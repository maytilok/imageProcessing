# %% [markdown]
# ##Multiple image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# Specify the path to your Excel file in Google Drive
file_path = '/content/drive/MyDrive/Food Image Analysis/Analysis/Image/Kfc/kfc_image_url_split.csv'

# Read the Excel file into a DataFrame
twitter_df = pd.read_csv(file_path)

# %%
#make URL list

image_urls = twitter_df['Tweet_Image_File'].values.tolist()

# %%
image_urls
# Out:
# ['https://pbs.twimg.com/media/DwWI4CaUcAAzVt4.jpg',
#  'https://pbs.twimg.com/media/DxkVK6KX4AMuJJl.jpg',
#  'https://pbs.twimg.com/media/Dy1metvU0AESUva.jpg',
#  'https://pbs.twimg.com/media/DzTwVoiV4AERCyN.jpg',
#  'https://pbs.twimg.com/media/DzTwVoiV4AERCyN.jpg',
#  'https://pbs.twimg.com/media/DzTwVoiV4AERCyN.jpg',
#  'https://pbs.twimg.com/media/D0267bPU0AEtQOB.jpg',
#  'https://pbs.twimg.com/media/D2spZ5fVYAAKqsT.jpg',
#  'https://pbs.twimg.com/amplify_video_thumb/1126218826205372416/img/Z6vxyMf9Hse-rFKS.jpg',
#  'https://pbs.twimg.com/media/D6ZZhFSU0AAJd76.jpg',
#  'https://pbs.twimg.com/amplify_video_thumb/1155940412567089152/img/iPkpdC_GktxKNj5h.jpg',
#  'https://pbs.twimg.com/media/EC6G8O0WsAA3lPj.jpg',
#  'https://pbs.twimg.com/ext_tw_video_thumb/1166459219555471362/pu/img/2ZVPVdrQ3oHvKJDe.jpg',
#  'https://pbs.twimg.com/ext_tw_video_thumb/1166459219555471362/pu/img/2ZVPVdrQ3oHvKJDe.jpg',
#  'https://pbs.twimg.com/tweet_video_thumb/EFPvEogVAAAKnes.jpg',
# ...

# %%
len(image_urls)
# Out:
# 355

# %%
import requests
import os
import cv2

# You can name the dir whatever you want
save_dir = '/content/drive/MyDrive/Food Image Analysis/Analysis/Image/Kfc/Kfc_Image'

# Validate that the directory exists
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# Function to download an image
def download_image(url, save_path):
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raises an error on a bad status
        with open(save_path, 'wb') as file:
            file.write(response.content)
        print(f"Image saved to {save_path}")
    except requests.RequestException as e:
        print(f"Failed to download {url}: {e}")

# Download each image
for i, url in enumerate(image_urls):
    #filename = f"image_{i+1}.jpg" # Feel free to replace each of the name
    filename = url.split('/')[-1]
    save_path = os.path.join(save_dir, filename)
    download_image(url, save_path)
# Out:
# Image saved to /content/drive/MyDrive/Food Image Analysis/Analysis/Image/Kfc/Kfc_Image/DwWI4CaUcAAzVt4.jpg
# Image saved to /content/drive/MyDrive/Food Image Analysis/Analysis/Image/Kfc/Kfc_Image/DxkVK6KX4AMuJJl.jpg
# Image saved to /content/drive/MyDrive/Food Image Analysis/Analysis/Image/Kfc/Kfc_Image/Dy1metvU0AESUva.jpg
# Image saved to /content/drive/MyDrive/Food Image Analysis/Analysis/Image/Kfc/Kfc_Image/DzTwVoiV4AERCyN.jpg
# Image saved to /content/drive/MyDrive/Food Image Analysis/Analysis/Image/Kfc/Kfc_Image/DzTwVoiV4AERCyN.jpg
# Image saved to /content/drive/MyDrive/Food Image Analysis/Analysis/Image/Kfc/Kfc_Image/DzTwVoiV4AERCyN.jpg
# Image saved to /content/drive/MyDrive/Food Image Analysis/Analysis/Image/Kfc/Kfc_Image/D0267bPU0AEtQOB.jpg
# Image saved to /content/drive/MyDrive/Food Image Analysis/Analysis/Image/Kfc/Kfc_Image/D2spZ5fVYAAKqsT.jpg
# Image saved to /content/drive/MyDrive/Food Image Analysis/Analysis/Image/Kfc/Kfc_Image/Z6vxyMf9Hse-rFKS.jpg
# ...
