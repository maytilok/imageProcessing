# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
from PIL import Image
import cv2
import os
import numpy as np

# %% [markdown]
# #The used one (below)

# %%
def get_image_resolution(image_path):
  results = []

  for path in image_files:
    img = Image.open(path)
    # get image size
    width, height = img.size
    # calculate resolution
    resolution = width*height
    results.append(width)
  return results

# %%
import cv2
import os
import pandas as pd

image_folder = "/content/drive/MyDrive/Food Image Analysis/Analysis/Image/Kfc/Kfc_Image"
image_files = [os.path.join(image_folder, f) for f in os.listdir(image_folder) if f.endswith(('.jpg', '.png'))]

resolution_results = get_image_resolution(image_files)

# Initialize an empty list to store the data
resolution_list = []

# Print results
for img, result in zip(image_files, resolution_results):
    data = {'image': img, 'resolution': result}
    resolution_list.append(data)  # Append the dictionary to the list

# %%
import pandas as pd

resolution_df = pd.DataFrame(resolution_list)
resolution_df
# Out:
#                                                  image  resolution
# 0    /content/drive/MyDrive/Food Image Analysis/Ana...         576
# 1    /content/drive/MyDrive/Food Image Analysis/Ana...        1080
# 2    /content/drive/MyDrive/Food Image Analysis/Ana...         531
# 3    /content/drive/MyDrive/Food Image Analysis/Ana...        1200
# 4    /content/drive/MyDrive/Food Image Analysis/Ana...         640
# ..                                                 ...         ...
# 348  /content/drive/MyDrive/Food Image Analysis/Ana...         261
# 349  /content/drive/MyDrive/Food Image Analysis/Ana...         388
# 350  /content/drive/MyDrive/Food Image Analysis/Ana...         506
# 351  /content/drive/MyDrive/Food Image Analysis/Ana...         506
# 352  /content/drive/MyDrive/Food Image Analysis/Ana...         506
#
# [353 rows x 2 columns]

# %%
resolution_df.groupby(['resolution'])['resolution'].count()
# Out:
# resolution
# 261       1
# 286       1
# 320       1
# 388       1
# 390       1
# 400       1
# 480       1
# 488       1
# 506       4
# 530       1
# 531       1
# 540       3
# 576       1
# 600       5
# 617       1
# 640       2
# 652       1
# 675       1
# 693       1
# 701       1
# 718       1
# 720      26
# 746       1
# 764       1
# 778       1
# 800       3
# 807       1
# 828       4
# 832       1
# 850       2
# 864       1
# 900       5
# 913       1
# 930       1
# 939       1
# 942       1
# 948       1
# 960      39
# 1000      1
# 1024      4
# 1025      1
# 1028      1
# 1038      1
# 1068      1
# 1074      1
# 1080    104
# 1125      1
# 1152      1
# 1160      2
# 1162      1
# 1176      1
# 1179      1
# 1199      1
# 1200    110
# Name: resolution, dtype: int64

# %%
resolution_df['image_url'] = resolution_df['image'].str.split('/').str[-1]
resolution_df
# Out:
#                                                  image  resolution  \
# 0    /content/drive/MyDrive/Food Image Analysis/Ana...      331776
# 1    /content/drive/MyDrive/Food Image Analysis/Ana...     1166400
# 2    /content/drive/MyDrive/Food Image Analysis/Ana...      339840
# 3    /content/drive/MyDrive/Food Image Analysis/Ana...     1440000
# 4    /content/drive/MyDrive/Food Image Analysis/Ana...      230400
# ..                                                 ...         ...
# 348  /content/drive/MyDrive/Food Image Analysis/Ana...       80388
# 349  /content/drive/MyDrive/Food Image Analysis/Ana...      151320
# 350  /content/drive/MyDrive/Food Image Analysis/Ana...      128018
# 351  /content/drive/MyDrive/Food Image Analysis/Ana...      128018
# 352  /content/drive/MyDrive/Food Image Analysis/Ana...      128018
#
#                image_url
# 0    DwWI4CaUcAAzVt4.jpg
# 1    DxkVK6KX4AMuJJl.jpg
# 2    Dy1metvU0AESUva.jpg
# 3    DzTwVoiV4AERCyN.jpg
# 4    D0267bPU0AEtQOB.jpg
# ...

# %%
resolution_df.drop('image', axis=1, inplace=True)
resolution_df
# Out:
#      resolution            image_url
# 0        331776  DwWI4CaUcAAzVt4.jpg
# 1       1166400  DxkVK6KX4AMuJJl.jpg
# 2        339840  Dy1metvU0AESUva.jpg
# 3       1440000  DzTwVoiV4AERCyN.jpg
# 4        230400  D0267bPU0AEtQOB.jpg
# ..          ...                  ...
# 348       80388  F5Df4PIbMAAZ2-y.jpg
# 349      151320  F7XO-hMbAAAb1bZ.jpg
# 350      128018  GM6ZA1RXAAAZBN0.jpg
# 351      128018  GM6ZDHeWIAAZYPU.jpg
# 352      128018  GM6ZEQIWcAAKZZR.jpg
#
# [353 rows x 2 columns]

# %%
resolution_df.to_csv('/content/drive/MyDrive/Food Image Analysis/Analysis/Image/Kfc/resolution_kfc.csv', index=False)
